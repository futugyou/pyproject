# %% [markdown]
# <a href="https://colab.research.google.com/github/futugyou/pyproject/blob/master/transformers_demo/try_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装所需的依赖库
# !pip install tokenizers
# !pip install transformers
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch

tokenizer = AutoTokenizer.from_pretrained("uer/gpt2-chinese-cluecorpussmall")
model = AutoModelForCausalLM.from_pretrained("uer/gpt2-chinese-cluecorpussmall")

generator = pipeline("text-generation",model=model,tokenizer=tokenizer,return_full_text=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/217 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/421M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/421M [00:00<?, ?B/s]
# Device set to use cpu

# %%
message = "生成一段计算闰年的c#代码"
output = generator(message)
print(output)
# Out:
# [{'generated_text': '生成一段计算闰年的c#代码 c # 写 一 份 对 象 的 程 序 ， 结 果 会 是 怎 样 的 ？ 如 果 一 个 程 序 写 了 一 段 计 算 闰 年 的 c 代 码 ， 结 果 会 是 怎 样 的 ？ （ 我 的 问 题 是 ， 如 果 一 个 程 序 写 了 一 段 计 算 闰 年 的 c 代 码 ， 结 果 会 是 怎 样 的 ？ ） 假 设 ， 一 个 程 序 写 了 一 段 程 序 ， 结 果 会 是 怎 样 的 ？ 一 个 程 序 写 了 一 段 算 法 的 代 码 ， 结 果 会 是 怎 样 的 ？ 如 果 程 序 写 了 一 段 程 序 ， 结 果 会 是 怎 样 的 ？ 如 果 一 个 程 序 写 了 一 段 算 法 的 代 码 ， 结 果 会 是 怎 样 的 ？ 首 先 在 一 个 程 序 里 面 ， 一 个 c 的 数 字 是 2 ， 这 个 数 字 是 2 ， 然 后 c 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后 c 的 数 字 是 2 ， 然 后'}]
