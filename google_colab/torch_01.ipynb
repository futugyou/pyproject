# %% [markdown]
# <a href="https://colab.research.google.com/github/futugyou/pyproject/blob/master/google_colab/torch_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install torch

# %%
import torch

torch.__version__

# %%
torch.cuda.is_available()

# %%
tensor0d = torch.tensor(1)
print(tensor0d.dtype)

floatvec = torch.tensor([1.0, 2.0, 3.0])
print(floatvec.dtype)

# %%
tensor2d = torch.tensor([[1, 2, 3], [4, 5, 6]])
print(tensor2d.shape)
print(tensor2d.reshape(3, 2))
print(tensor2d.view(3 ,2))
print(tensor2d.T)
print(tensor2d.matmul(tensor2d.T))
print(tensor2d @ tensor2d.T)
